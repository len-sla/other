# %% [markdown]
# Update to tables library-pandas need that to avoid write errors

# %%
# !pip install --upgrade tables
# Out:
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (3.4.4)
# Collecting tables
#   Downloading tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 6.4 MB/s
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.7/dist-packages (from tables) (1.19.5)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables) (2.7.3)
# Installing collected packages: tables
#   Attempting uninstall: tables
#     Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %% [markdown]
# # OLX portal web page scraper

# %% [markdown]
# Upgrading pandas so there is no problem with writing

# %% [markdown]
# ## Mount drive

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import libraries

# %%
# from bs4 import BeautifulSoup

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

import pandas as pd
import numpy  as np
import re
import datetime
import os,glob
import json
from json.decoder import JSONDecodeError
from tqdm import tqdm
import re

# %% [markdown]
# ## Beautify

# %%
start_url= 'https://www.olx.pl/nieruchomosci/zukowo/q-dzia%C5%82ka-rolna/?search%5Border%5D=filter_float_price%3Aasc&search%5Bdist%5D=50&view=list'

# %%
# makes the source tree format like

def beautify(url):
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = Request(url,headers=hdr)
    page = urlopen(req)

    return BeautifulSoup(page, "html.parser")

# %%
plots = beautify(start_url)

# %% [markdown]
# ## Scrap table and put to lists

# %%
table = plots.find('table', {'class': "fixed offers breakword redesigned"})
for row in table.findAll("href"):
  print(row.get)

# %%
# giving all th erow also empty no text

table_rows = table.find_all('tr')

res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [d.text.strip() for d in td]
    res.append(row)

# %% [markdown]
# lets remove duplicates

# %%
result = [] 
for nr, link in enumerate(table.find_all('a')):
  if link.get('href').__contains__('/oferta/'): # specific text which needs to be in the link
    if link.get('href') not in result:  # avoiding duplicates
      result.append(link.get('href'))
result
# Out:
# ['https://www.olx.pl/d/oferta/dzialka-rolna-kaszuby-CID3-IDKR9oX.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-rolna-ulkowy-CID3-IDKL0l5.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-budowlana-wicko-3089m2-na-wzgorzu-blisko-leba-okazja-CID3-IDBMymF.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-budowlana-dzialki-budowlane-dzialka-rolna-CID3-IDJQ04F.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-rolna-maszewko-gm-wicko-grunt-1ha-10-000m2-krus-kopaniewo-leba-CID3-IDDMk7s.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-karwienskie-blota-2-CID3-IDK55wR.html#8f26caf238;promoted',
#  'https://www.olx.pl/d/oferta/dzialka-rolna-siedlisko-w-zaciszu-z-dala-od-cywilizacji-CID3-IDK32n5.html#8f26caf238',
#  'https://www.otodom.pl/pl/oferta/malownicza-dzialka-w-otoczeniu-pol-w-zblewie-ID4cqHj.html?',
#  'https://www.olx.pl/d/oferta/dzialka-rolna-siedlisko-w-zaciszu-CID3-IDK2Yvd.html#8f26caf238',
#  'https://www.olx.pl/d/oferta/dzialka-w-przepieknej-lokalizacji-CID3-IDKoOLp.html#8f26caf238',
#  'https://www.otodom.pl/pl/oferta/dzialka-nad-jeziorem-linia-brzegowa-17000m2-lipusz-ID487xu.html?',
#  'https://www.otodom.pl/pl/oferta/dzialka-rolna-2ha-pod-fotowoltaike-gdansk-ID3WqPm.html?',
#  'https://www.olx.pl/d/oferta/donimierz-dzialka-rolna-3-7594-ha-blisko-trasy-s6-CID3-IDKO64D.html#8f26caf238',
#  'https://www.otodom.pl/pl/oferta/dzialka-rolna-pod-fotowoltaike-przy-panattoni-ID46RuI.html?',
#  'https://www.otodom.pl/pl/oferta/dzialka-57600m-karolewo-gm-zblewo-pow-star-gd-ID4a0Yx.html?']

# %% [markdown]
# old version

# %%
# and funcion doing removing extra spaces and new lines

def remove_extra(temp):
  temp = re.sub(r'\n+', ' ', temp) #removing extra new lines
  temp = re.sub(r' +', ' ', temp)  #removing extra spaces
  return temp

# %%
# retrieving info with regex to the tables
l_cena=[]
l_date_=[]
l_descr=[]

for nr, i in enumerate(res):
  if len(i)>3:
    cena= re.findall(r".+zł", i[0])
    date_= re.findall(r"\d+\s{2}\w{3}|.*\d+:\d+", i[0])
    descr= i=remove_extra(i[0])

    l_cena.append(cena)
    l_date_.append(date_)
    l_descr.append(descr)

    # print( cena[0].ljust(15), date_[0].ljust(15), descr)

# %% [markdown]
# ## Print results from lists

# %%
for nr, i in enumerate(result):
  print(str(nr).ljust(2),
        result[nr].ljust(130),
        l_cena[nr],
        l_date_[nr],
        l_descr[nr])
# Out:
# 0  https://www.olx.pl/d/oferta/dzialka-rolna-kaszuby-CID3-IDKR9oX.html#8f26caf238                                                     ['30 000 zł'] ['wczoraj 07:36'] Dzialka rolna Kaszuby Działki » Sprzedaż 30 000 zł Borucino wczoraj 07:36
# 1  https://www.olx.pl/d/oferta/dzialka-rolna-ulkowy-CID3-IDKL0l5.html#8f26caf238                                                      ['35 000 zł'] ['12  sie'] Działka rolna Ulkowy Działki » Sprzedaż 35 000 zł Do negocjacji Ulkowy 12 sie
# 2  https://www.olx.pl/d/oferta/dzialka-budowlana-wicko-3089m2-na-wzgorzu-blisko-leba-okazja-CID3-IDBMymF.html#8f26caf238              ['49 999 zł'] ['6  sie'] Działka budowlana Wicko 3089m2 na wzgórzu (blisko Łeba) OKAZJA Działki » Sprzedaż 49 999 zł Do negocjacji Lębork 6 sie
# 3  https://www.olx.pl/d/oferta/dzialka-budowlana-dzialki-budowlane-dzialka-rolna-CID3-IDJQ04F.html#8f26caf238                         ['50 000 zł'] ['11  sie'] Działka budowlana działki budowlane działka rolna Działki » Sprzedaż 50 000 zł Mściszewice 11 sie
# 4  https://www.olx.pl/d/oferta/dzialka-rolna-maszewko-gm-wicko-grunt-1ha-10-000m2-krus-kopaniewo-leba-CID3-IDDMk7s.html#8f26caf238    ['55 900 zł'] ['7  sie'] Działka rolna Maszewko gm Wicko grunt 1ha 10.000m2 Krus Kopaniewo Łeba Działki » Sprzedaż 55 900 zł Maszewko 7 sie
# 38 https://www.otodom.pl/pl/oferta/dzialka-57600m-karolewo-gm-zblewo-pow-star-gd-ID4a0Yx.html?                                        ['2 246 400 zł'] ['14  sie'] Działka 57600m² /Karolewo/gm. Zblewo/pow. Star.Gd Działki » Sprzedaż 2 246 400 zł Karolewo 14 sie

# %% [markdown]
# # Saving results to file

# %%
plots_olx_pd = pd.DataFrame({'web_link' : result,
                               'price' : l_cena,
                               'time' : l_date_,
                               'Description': l_descr})

# %%
# plots_olx_pd

# %%
# generating file name with timestamp info for later comparison
def gen_h5_file_with_timestamp(name='name'):
    timestamp = datetime.datetime.now()
    ts1 = timestamp.strftime("%A%d%B%Y%m")
    ts2 = timestamp.strftime("%H")
    ts3 = timestamp.strftime("%M")
    ts4 = timestamp.strftime("%S")
    file_name= name + ts1 +"-"+ ts2+"-"+ ts3+"-"+ ts4+".h5"
    return file_name

# %%
file_name= gen_h5_file_with_timestamp(name='agro_plots_olx_')
file_name
# Out:
# 'agro_plots_olx_Friday20August202108-09-57-04.h5'

# %%
plots_olx_pd.to_hdf('/content/drive/MyDrive/olx-scrap/scraped/'+file_name, key='df', mode='w')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['web_link', 'price', 'time', 'Description'], dtype='object')]
#
#   encoding=encoding,

# %% [markdown]
# # Checking changes since last time

# %%
# preparing list of existing(previously created by scrapping) pandas linkedin .h5 files
search_dir = "/content/drive/MyDrive/olx-scrap/scraped/" #directory where from where h5 is read s
def list_per_time(search_dir=search_dir):
    files = [x for x in (filter(os.path.isfile, glob.glob(search_dir + "agro*.h5"))) ] 
    files_sorted= sorted(files, key=os.path.getmtime)
    print(files_sorted[:10])
    return files_sorted

# %%
# loading last( creation time) two dfs for comparison
def read_two_last_dfs():
    files_sorted=list_per_time()
    f1=files_sorted[-2:-1]
    f2=files_sorted[-1:]
    df1=pd.read_hdf(f1[0], 'df')
    df2=pd.read_hdf(f2[0], 'df')
    return df1, df2

# %%
df1, df2=read_two_last_dfs()
# Out:
# ['/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Wednesday18August202108-10-13-54.h5', '/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Wednesday18August202108-19-10-12.h5', '/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Thursday19August202108-11-08-48.h5', '/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Friday20August202108-09-57-04.h5']

# %%
print('=============links to new jobs since last checking=============\n')
for x,item in enumerate(df2.web_link.values[~df2['web_link'].isin(df1['web_link'])]):
    print(x, '-->',item )
# Out:
# =============links to new jobs since last checking=============
#
# 0 --> https://www.otodom.pl/pl/oferta/malownicza-dzialka-w-otoczeniu-pol-w-zblewie-ID4cqHj.html?
# 1 --> https://www.olx.pl/d/oferta/dzialka-z-blotkiem-CID3-IDL093I.html#8f26caf238
# 2 --> https://www.otodom.pl/pl/oferta/dzialka-57600m-karolewo-gm-zblewo-pow-star-gd-ID4a0Yx.html?

# %% [markdown]
# Checking differece to 18/08/2021

# %%
new_plots=[]
df_ref = pd.read_hdf('/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Wednesday18August202108-10-13-54.h5', 'df')
print('=============links to new jobs since 18/08/2021 =============\n')
for x,item in enumerate(df2.web_link.values[~df2['web_link'].isin(df_ref['web_link'])]):
  new_plots.append(item)
  print(x, '-->',item )
# Out:
# =============links to new jobs since 18/08/2021 =============
#
# 0 --> https://www.otodom.pl/pl/oferta/malownicza-dzialka-w-otoczeniu-pol-w-zblewie-ID4cqHj.html?
# 1 --> https://www.olx.pl/d/oferta/dzialka-z-blotkiem-CID3-IDL093I.html#8f26caf238
# 2 --> https://www.olx.pl/d/oferta/donimierz-dzialka-rolna-3-7594-ha-blisko-trasy-s6-CID3-IDKO64D.html#8f26caf238
# 3 --> https://www.otodom.pl/pl/oferta/dzialka-rolna-pod-fotowoltaike-przy-panattoni-ID46RuI.html?
# 4 --> https://www.otodom.pl/pl/oferta/dzialka-57600m-karolewo-gm-zblewo-pow-star-gd-ID4a0Yx.html?

# %% [markdown]
# What will be diffrence if df1 and 2 were changed places (what dissapeared...)

# %%
dissapeared=[]
df_ref = pd.read_hdf('/content/drive/MyDrive/olx-scrap/scraped/agro_plots_olx_Wednesday18August202108-10-13-54.h5', 'df')
print('=============those dissaperarewd since 18/06/2021 =============\n')
for x,item in enumerate(df_ref.web_link.values[~df_ref['web_link'].isin(df2['web_link'])]):
  dissapeared.append(item)
  print(x, '-->',item,  )
  print(df_ref[df_ref.web_link==item].Description.values)
# Out:
# =============those dissaperarewd since 18/06/2021 =============
#
# 0 --> https://www.olx.pl/d/oferta/dzialka-i-nad-morzem-CID3-IDKxhWE.html#8f26caf238
# ['Działka/i nad morzem Działki » Sprzedaż 97 000 zł Do negocjacji Sobieńczyce 25 lip']
# 1 --> https://www.olx.pl/d/oferta/dzialka-z-blotkiem-CID3-IDL093I.html#8f26caf238;promoted
# ['Brak zdjęcia Działka z błotkiem Działki » Sprzedaż 100 000 zł Grabowska Huta 16 sie']
# 2 --> https://www.olx.pl/d/oferta/dzialka-5100m2-laka-CID3-IDKdQdS.html#8f26caf238
# ['Działka 5100m2 łąka Działki » Sprzedaż 149 000 zł Do negocjacji Reda 3 sie']
# 3 --> https://www.otodom.pl/pl/oferta/piekna-duza-dzialka-nad-jeziorem-poleczynskim-ID4bLF2.html?
# ['Piękna duża działka nad jeziorem Połęczyńskim Działki » Sprzedaż 168 000 zł Połęczyno 9 sie']
# 4 --> https://www.otodom.pl/pl/oferta/dzialka-1-ha-z-kawalkiem-lasu-blisko-gdanska-ID3YEAM.html?
# ['Działka 1 Ha z kawałkiem lasu blisko Gdańska Działki » Sprzedaż 325 000 zł Przywidz dzisiaj 07:34']

# %% [markdown]
# Checking if new plots are only the change  from promoted?

# %%
for plot in dissapeared:
  for new_p in new_plots:
    if plot.__contains__(new_p):
      print('is-->',new_p ,'  --was--->',plot)
# Out:
# is--> https://www.olx.pl/d/oferta/dzialka-z-blotkiem-CID3-IDL093I.html#8f26caf238   --was---> https://www.olx.pl/d/oferta/dzialka-z-blotkiem-CID3-IDL093I.html#8f26caf238;promoted
